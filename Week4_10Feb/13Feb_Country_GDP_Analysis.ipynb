# %%
import pandas as pd
print("Pandas version = ",pd.__version__)
# Out:
# Pandas version =  2.2.2

# %%
gdp_file = pd.read_csv(r'C:\Users\bmittipa\Documents\Vodafone\PrakashSenapati\Python_Learning\Week4_10Feb\CountryGDPAnalysis\Sample-Country_GDP.csv')

# %%
gdp_file
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
gdp_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
len(gdp_file)
# Out:
# 195

# %%
gdp_file.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
print("Shape = ",gdp_file.shape)
print("Dimensions = ",gdp_file.ndim)
print("ID  = ",id(gdp_file))
# Out:
# Shape =  (195, 5)
# Dimensions =  2
# ID  =  2129573162944

# %%
gdp_file.info
# Out:
# <bound method DataFrame.info of               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
gdp_file.describe
# Out:
# <bound method NDFrame.describe of               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
gdp_file.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
gdp_file.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
print("\nFile HEAD = ",gdp_file.head())
print("\nFile TAIL = ",gdp_file.tail())
print("\nFile Head with args = ",gdp_file.head(100))
print("\nFile Tail with args = ",gdp_file.tail(100))
# Out:
# File HEAD =              CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
#
# File TAIL =            CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# ...

# %%
gdp_file[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
gdp_file[:5]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
gdp_file[0:200:10]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %% [markdown]
# ##### Descriptive Statistics..Gives Numerical Info
# gdp_file.describe()

# %%
gdp_file.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
gdp_file.describe().transpose()
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
gdp_file.columns=['Country Name','Country Code','Birth Rate','Internet Users','Income Group']

# %%
gdp_file.describe()
# Out:
#        Birth Rate  Internet Users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
my_subset = gdp_file[['Birth Rate', 'Internet Users']]
my_subset
# Out:
#      Birth Rate  Internet Users
# 0        10.244            78.9
# 1        35.253             5.9
# 2        45.985            19.1
# 3        12.877            57.2
# 4        11.044            88.0
# ..          ...             ...
# 190      32.947            20.0
# 191      20.850            46.5
# 192      42.394             2.2
# 193      40.471            15.4
# 194      35.715            18.5
#
# [195 rows x 2 columns]

# %%
gdp_file.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth Rate', 'Internet Users',
#        'Income Group'],
#       dtype='object')

# %%
categ_data = ['Country Name', 'Country Code','Income Group']
gdp_file[categ_data].head()
# Out:
#            Country Name Country Code         Income Group
# 0                 Aruba          ABW          High income
# 1           Afghanistan          AFG           Low income
# 2                Angola          AGO  Upper middle income
# 3               Albania          ALB  Upper middle income
# 4  United Arab Emirates          ARE          High income

# %%
num_data = ['Birth Rate', 'Internet Users']
gdp_file[num_data]
# Out:
#      Birth Rate  Internet Users
# 0        10.244            78.9
# 1        35.253             5.9
# 2        45.985            19.1
# 3        12.877            57.2
# 4        11.044            88.0
# ..          ...             ...
# 190      32.947            20.0
# 191      20.850            46.5
# 192      42.394             2.2
# 193      40.471            15.4
# 194      35.715            18.5
#
# [195 rows x 2 columns]

# %%
gdp_file[categ_data].describe()
# Out:
#        Country Name Country Code Income Group
# count           195          195          195
# unique          195          195            4
# top           Aruba          ABW  High income
# freq              1            1           67

# %%
gdp_file[num_data].describe()
# Out:
#        Birth Rate  Internet Users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
gdp_file[categ_data].describe().transpose()
# Out:
#              count unique          top freq
# Country Name   195    195        Aruba    1
# Country Code   195    195          ABW    1
# Income Group   195      4  High income   67

# %%
gdp_file[num_data].describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth Rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet Users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth Rate      49.6610
# Internet Users  96.5468

# %%
gdp_file.head()
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
gdp_file.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth Rate', 'Internet Users',
#        'Income Group'],
#       dtype='object')

# %%
gdp_file[['Country Name','Country Code', 'Income Group']]
# Out:
#              Country Name Country Code         Income Group
# 0                   Aruba          ABW          High income
# 1             Afghanistan          AFG           Low income
# 2                  Angola          AGO  Upper middle income
# 3                 Albania          ALB  Upper middle income
# 4    United Arab Emirates          ARE          High income
# ..                    ...          ...                  ...
# 190           Yemen, Rep.          YEM  Lower middle income
# 191          South Africa          ZAF  Upper middle income
# 192      Congo, Dem. Rep.          COD           Low income
# 193                Zambia          ZMB  Lower middle income
# 194              Zimbabwe          ZWE           Low income
#
# [195 rows x 3 columns]

# %%
['Country Name', 'Country Code']
# Out:
# ['Country Name', 'Country Code']

# %%
gdp_file[['Country Name', 'Country Code']]
# Out:
#              Country Name Country Code
# 0                   Aruba          ABW
# 1             Afghanistan          AFG
# 2                  Angola          AGO
# 3                 Albania          ALB
# 4    United Arab Emirates          ARE
# ..                    ...          ...
# 190           Yemen, Rep.          YEM
# 191          South Africa          ZAF
# 192      Congo, Dem. Rep.          COD
# 193                Zambia          ZMB
# 194              Zimbabwe          ZWE
#
# [195 rows x 2 columns]

# %%
gdp_file[4:8][['Country Name', 'Country Code']]
# Out:
#            Country Name Country Code
# 4  United Arab Emirates          ARE
# 5             Argentina          ARG
# 6               Armenia          ARM
# 7   Antigua and Barbuda          ATG

# %%
gdp_file[['Country Name', 'Country Code']][4:8]
# Out:
#            Country Name Country Code
# 4  United Arab Emirates          ARE
# 5             Argentina          ARG
# 6               Armenia          ARM
# 7   Antigua and Barbuda          ATG

# %%
gdp_file.head()
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
gdp_file.columns=['Country Name','Country Code','BirthRate','InternetUsers','Income Group']

# %%
gdp_file.head()
# Out:
#            Country Name Country Code  BirthRate  InternetUsers  \
# 0                 Aruba          ABW     10.244           78.9
# 1           Afghanistan          AFG     35.253            5.9
# 2                Angola          AGO     45.985           19.1
# 3               Albania          ALB     12.877           57.2
# 4  United Arab Emirates          ARE     11.044           88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
gdp_file["Total"] = gdp_file.BirthRate * gdp_file.InternetUsers

# %%
gdp_file.head()
# Out:
#            Country Name Country Code  BirthRate  InternetUsers  \
# 0                 Aruba          ABW     10.244           78.9
# 1           Afghanistan          AFG     35.253            5.9
# 2                Angola          AGO     45.985           19.1
# 3               Albania          ALB     12.877           57.2
# 4  United Arab Emirates          ARE     11.044           88.0
#
#           Income Group     Total
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
gdp_file.columns
# Out:
# Index(['Country Name', 'Country Code', 'BirthRate', 'InternetUsers',
#        'Income Group', 'Total'],
#       dtype='object')

# %%
len(gdp_file.columns)
# Out:
# 6

# %%
gdp_file.drop('Total',axis=1)
# Out:
#              Country Name Country Code  BirthRate  InternetUsers  \
# 0                   Aruba          ABW     10.244           78.9
# 1             Afghanistan          AFG     35.253            5.9
# 2                  Angola          AGO     45.985           19.1
# 3                 Albania          ALB     12.877           57.2
# 4    United Arab Emirates          ARE     11.044           88.0
# ..                    ...          ...        ...            ...
# 190           Yemen, Rep.          YEM     32.947           20.0
# 191          South Africa          ZAF     20.850           46.5
# 192      Congo, Dem. Rep.          COD     42.394            2.2
# 193                Zambia          ZMB     40.471           15.4
# 194              Zimbabwe          ZWE     35.715           18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
gdp_file.columns[3:4]
# Out:
# Index(['InternetUsers'], dtype='object')

# %%
gdp_file.head()
# Out:
#            Country Name Country Code  BirthRate  InternetUsers  \
# 0                 Aruba          ABW     10.244           78.9
# 1           Afghanistan          AFG     35.253            5.9
# 2                Angola          AGO     45.985           19.1
# 3               Albania          ALB     12.877           57.2
# 4  United Arab Emirates          ARE     11.044           88.0
#
#           Income Group     Total
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
gdp_file.columns=['CountryName','CountryCode','BirthRate','InternetUsers','IncomeGroup','Total']

# %%
gdp_file[gdp_file.InternetUsers < 10]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 15                 Bangladesh         BGD     20.142           6.63
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 46                   Djibouti         DJI     25.486           9.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# ...

# %%
len(gdp_file[gdp_file.InternetUsers < 10])
# Out:
# 38

# %%
gdp_file[gdp_file.InternetUsers > 40]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244           78.9
# 3                  Albania         ALB     12.877           57.2
# 4     United Arab Emirates         ARE     11.044           88.0
# 5                Argentina         ARG     17.716           59.9
# 6                  Armenia         ARM     13.308           41.9
# ..                     ...         ...        ...            ...
# 184          Venezuela, RB         VEN     19.842           54.9
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 188     West Bank and Gaza         PSE     30.394           46.6
# 191           South Africa         ZAF     20.850           46.5
#
#              IncomeGroup      Total
# 0            High income   808.2516
# 3    Upper middle income   736.5644
# 4            High income   971.8720
# 5            High income  1061.1884
# ...

# %%
Filter1 = gdp_file.InternetUsers < 2
Filter2 = gdp_file.BirthRate > 40

# %%
Filter1 & Filter2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
gdp_file[Filter1 & Filter2]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup    Total
# 11      Burundi         BDI     44.151            1.3  Low income  57.3963
# 127       Niger         NER     49.661            1.7  Low income  84.4237
# 156     Somalia         SOM     43.891            1.5  Low income  65.8365

# %%
gdp_file[gdp_file.IncomeGroup == 'Low income']
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 64                     Guinea         GIN     37.337           1.60
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# ...

# %%
fil1 = gdp_file.IncomeGroup == 'Low income'
fil2 = gdp_file.IncomeGroup == 'High income'
gdp_file[fil1 | fil2]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup  \
# 0                    Aruba         ABW     10.244           78.9  High income
# 1              Afghanistan         AFG     35.253            5.9   Low income
# 4     United Arab Emirates         ARE     11.044           88.0  High income
# 5                Argentina         ARG     17.716           59.9  High income
# 7      Antigua and Barbuda         ATG     16.447           63.4  High income
# ..                     ...         ...        ...            ...          ...
# 181          United States         USA     12.500           84.2  High income
# 184          Venezuela, RB         VEN     19.842           54.9  High income
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3  High income
# 192       Congo, Dem. Rep.         COD     42.394            2.2   Low income
# 194               Zimbabwe         ZWE     35.715           18.5   Low income
#
#          Total
# 0     808.2516
# ...

# %%
gdp_file.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
gdp_file.IncomeGroup.nunique()
# Out:
# 4

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline
plt.rcParams['figure.figsize'] = 6,2

import warnings
warnings.filterwarnings('ignore')

# %%
gdp_file.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup     Total
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
gdp_file['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
# LOC
gdp_file.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup     Total
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
gdp_file.loc[2,'IncomeGroup']
# Out:
# 'Upper middle income'

# %%
gdp_file.loc[2,['IncomeGroup','CountryCode','BirthRate']]
# Out:
# IncomeGroup    Upper middle income
# CountryCode                    AGO
# BirthRate                   45.985
# Name: 2, dtype: object

# %%
gdp_file.iloc[2,0]
# Out:
# 'Angola'

# %%
gdp_file.iloc[2,:]
# Out:
# CountryName                   Angola
# CountryCode                      AGO
# BirthRate                     45.985
# InternetUsers                   19.1
# IncomeGroup      Upper middle income
# Total                       878.3135
# Name: 2, dtype: object

# %%
gdp_file.at[2,'IncomeGroup']
# Out:
# 'Upper middle income'

# %%
gdp_file.at[2,['IncomeGroup','CountryCode','BirthRate']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28288\3125045641.py in ?()
# ----> 1 gdp_file.at[2,['IncomeGroup','CountryCode','BirthRate']]
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, key)
#    2571             if not isinstance(key, tuple) or not all(is_scalar(x) for x in key):
#    2572                 raise ValueError("Invalid call for scalar access (getting)!")
#    2573             return self.obj.loc[key]
#    2574
# -> 2575         return super().__getitem__(key)
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, key)
#    2523             else:
#    2524                 raise ValueError("Invalid call for scalar access (getting)!")
#    2525
#    2526         key = self._convert_key(key)
# -> 2527         return self.obj._get_value(*key, takeable=self._takeable)
#
# ...

# %%
gdp_file.loc[2,['BirthRate']]
# Out:
# BirthRate    45.985
# Name: 2, dtype: object

# %%
gdp_file.iat[2,2]
# Out:
# 45.985

# %%
gdp_file.iat[2,:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 gdp_file.iat[2,:]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2526, in _ScalarAccessIndexer.__getitem__(self, key)
#    2523     else:
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
# -> 2526 key = self._convert_key(key)
#    2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2599, in _iAtIndexer._convert_key(self, key)
#    2597 for i in key:
#    2598     if not is_integer(i):
# -> 2599         raise ValueError("iAt based indexing can only have integer indexers")
#    2600 return key
#
# ValueError: iAt based indexing can only have integer indexers

# %%
gdp_file.head()

# %%
gdp_file.query('BirthRate > 20')

# %%
vis1 = sns.histplot(gdp_file['InternetUsers'])
plt.show()

# %%
vis1 = sns.distplot(gdp_file['InternetUsers'])
plt.show()

# %%
sns.distplot(gdp_file['InternetUsers'],bins=10)
plt.show()

# %%
sns.boxplot(data = gdp_file,x='IncomeGroup',y='BirthRate')
plt.show()

# %%
sns.lmplot(data=gdp_file,x='InternetUsers',y='BirthRate')
plt.show()

# %%
sns.lmplot(data=gdp_file,x='InternetUsers',y='BirthRate',fit_reg=False)
plt.show()

# %%
sns.lineplot(data=gdp_file,x='InternetUsers',y='BirthRate')
plt.show()

# %%
sns.lmplot(data=gdp_file,x='InternetUsers',y='BirthRate',hue='IncomeGroup')
plt.show()

# %%
sns.lmplot(data=gdp_file,x='InternetUsers',y='BirthRate',hue='IncomeGroup',fit_reg=False)
plt.show()
