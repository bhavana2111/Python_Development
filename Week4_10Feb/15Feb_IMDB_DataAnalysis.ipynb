# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
ratings = pd.read_csv(r'C:\Users\bmittipa\Documents\Vodafone\PrakashSenapati\Python_Learning\Week4_10Feb\IMDB_Movie_Analysis\archive\rating.csv')

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
movies = pd.read_csv(r'C:\Users\bmittipa\Documents\Vodafone\PrakashSenapati\Python_Learning\Week4_10Feb\IMDB_Movie_Analysis\archive\movie.csv')

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
tags = pd.read_csv(r'C:\Users\bmittipa\Documents\Vodafone\PrakashSenapati\Python_Learning\Week4_10Feb\IMDB_Movie_Analysis\archive\tag.csv')
tags
# Out:
#         userId  movieId            tag            timestamp
# 0           18     4141    Mark Waters  2009-04-24 18:19:40
# 1           65      208      dark hero  2013-05-10 01:41:18
# 2           65      353      dark hero  2013-05-10 01:41:19
# 3           65      521  noir thriller  2013-05-10 01:39:43
# 4           65      592      dark hero  2013-05-10 01:41:18
# ...        ...      ...            ...                  ...
# 465559  138446    55999        dragged  2013-01-23 23:29:32
# 465560  138446    55999  Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999         quirky  2013-01-23 23:29:38
# 465562  138446    55999            sad  2013-01-23 23:29:32
# 465563  138472      923  rise to power  2007-11-02 21:12:47
#
# [465564 rows x 4 columns]

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
row_at_location = tags.loc[0]
row_at_location
# Out:
# userId                        18
# movieId                     4141
# tag                  Mark Waters
# timestamp    2009-04-24 18:19:40
# Name: 0, dtype: object

# %%
user_id = tags.loc[0,'userId']
user_id
# Out:
# 18

# %%
tags.loc[tags.movieId == 521]
# Out:
#         userId  movieId                tag            timestamp
# 3           65      521      noir thriller  2013-05-10 01:39:43
# 1328       558      521           neo-noir  2013-05-08 05:47:58
# 31451     7671      521      noir thriller  2013-05-17 15:35:15
# 39105    10164      521           neo-noir  2013-05-09 01:50:10
# 60104    12999      521      noir thriller  2013-05-16 17:57:34
# 62006    14280      521      noir thriller  2013-05-17 07:20:06
# 64056    14517      521      noir thriller  2013-05-10 18:34:39
# 69111    16231      521           neo-noir  2013-05-09 14:40:22
# 92268    23333      521      noir thriller  2013-05-16 00:32:10
# 94799    24112      521           neo-noir  2013-05-09 00:19:19
# 97576    25004      521      noir thriller  2013-05-17 16:52:01
# 128580   33736      521   Nudity (Topless)  2006-09-20 06:43:54
# 153051   44112      521      noir thriller  2013-05-13 22:07:11
# 156692   45928      521        Gary Oldman  2007-06-08 15:13:04
# ...

# %%
tags.loc[tags.movieId == 521,['userId','tag']]
# Out:
#         userId                tag
# 3           65      noir thriller
# 1328       558           neo-noir
# 31451     7671      noir thriller
# 39105    10164           neo-noir
# 60104    12999      noir thriller
# 62006    14280      noir thriller
# 64056    14517      noir thriller
# 69111    16231           neo-noir
# 92268    23333      noir thriller
# 94799    24112           neo-noir
# 97576    25004      noir thriller
# 128580   33736   Nudity (Topless)
# 153051   44112      noir thriller
# 156692   45928        Gary Oldman
# 168529   50616           neo-noir
# 173644   52698           neo-noir
# 183938   54586      noir thriller
# 195169   58612  Annabella Sciorra
# 195170   58612          anti-hero
# 195171   58612           assassin
# 195172   58612         corruption
# 195173   58612        crooked cop
# 195174   58612           cynicism
# 195175   58612        Gary Oldman
# 195176   58612     Juliette Lewis
# 195177   58612          Lena Olin
# ...

# %%
#ILOC
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
row4 = tags.iloc[4]
print(row4)
print(row4.index)
print(row4.userId,row4.movieId,row4["tag"],row4["timestamp"])
# Out:
# userId                        65
# movieId                      592
# tag                    dark hero
# timestamp    2013-05-10 01:41:18
# Name: 4, dtype: object
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')
# 65 592 dark hero 2013-05-10 01:41:18

# %%
row4_tag = tags.iloc[4,2]
row4_tag
# Out:
# 'dark hero'

# %%
row5 = tags.iloc[5]
row5.head()
# Out:
# userId                        65
# movieId                      668
# tag                    bollywood
# timestamp    2013-05-10 01:37:56
# Name: 5, dtype: object

# %%
'tag' in row5
# Out:
# True

# %%
'HeroName' in row5
# Out:
# False

# %%
row5.name
# Out:
# 5

# %%
row5 = row5.rename('Row5')
row5.name
# Out:
# 'Row5'

# %%
tags.head(10)
# Out:
#    userId  movieId               tag            timestamp
# 0      18     4141       Mark Waters  2009-04-24 18:19:40
# 1      65      208         dark hero  2013-05-10 01:41:18
# 2      65      353         dark hero  2013-05-10 01:41:19
# 3      65      521     noir thriller  2013-05-10 01:39:43
# 4      65      592         dark hero  2013-05-10 01:41:18
# 5      65      668         bollywood  2013-05-10 01:37:56
# 6      65      898  screwball comedy  2013-05-10 01:42:40
# 7      65     1248     noir thriller  2013-05-10 01:39:43
# 8      65     1391              mars  2013-05-10 01:40:55
# 9      65     1617          neo-noir  2013-05-10 01:43:37

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
#Fetch More Data
tags.iloc[[10,25,987,1109]]
# Out:
#       userId  movieId                tag            timestamp
# 10        65     1694              jesus  2013-05-10 01:38:45
# 25        65     8622  conspiracy theory  2013-05-10 02:01:06
# 987      359    63033      'stop wanking  2009-04-27 09:45:57
# 1109     409    59315              funny  2012-05-07 19:59:02

# %%
# Descriptive Statistics
ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
# Ratings Categorical data description
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
print(ratings['rating'].mean())
print(ratings['rating'].sum())
print(ratings['rating'].std())
print(ratings['rating'].min())
print(ratings['rating'].max())
# Out:
# 3.5255285642993797
# 70511498.5
# 1.051988919275684
# 0.5
# 5.0

# %%
#ratings.mean()

# %%
#ratings.corr()

# %%
del ratings['timestamp']
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter1 = ratings['rating'] > 10
print(filter1)
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool

# %%
filter1 = ratings['rating'] > 10
ratings[filter1]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating]
# Index: []

# %%
filter1 = ratings['rating'] > 4
ratings[filter1]
# Out:
#           userId  movieId  rating
# 30             1     1196     4.5
# 31             1     1198     4.5
# 131            1     4993     5.0
# 142            1     5952     5.0
# 158            1     7153     5.0
# ...          ...      ...     ...
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000261  138493    70286     5.0
#
# [4433484 rows x 3 columns]

# %%
# Any item with rating > 10
filter1 = ratings['rating'] > 10
filter1.any()
# Out:
# False

# %%
# Any item with rating > 10
filter2 = ratings['rating'] > 0
filter2.any()
# Out:
# True

# %%
# Are 'all' indices with rating > 0?
filter2.all()
# Out:
# True

# %%
# Are All item with rating > 4
filter3 = ratings['rating'] > 4
filter3.all()
# Out:
# False

# %%
# DATA CLEANING--> HANDLING MISSING DATA
movies.shape
# Out:
# (27278, 3)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  27278 non-null  int64
#  1   title    27278 non-null  object
#  2   genres   27278 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 639.5+ KB

# %%
movies.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
ratings.isnull().any().any()
# Out:
# False

# %%
ratings.isnull().sum()
# Out:
# userId     0
# movieId    0
# rating     0
# dtype: int64

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465564 entries, 0 to 465563
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     465564 non-null  int64
#  1   movieId    465564 non-null  int64
#  2   tag        465548 non-null  object
#  3   timestamp  465564 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 14.2+ MB

# %%
tags.isnull().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
tags.isnull().any()
# Out:
# userId       False
# movieId      False
# tag           True
# timestamp    False
# dtype: bool

# %%
tags.isnull().any().any()
# Out:
# True

# %%
# DROP ALL NULL VALUES
tags = tags.dropna()

# %%
tags.isnull().any()
# Out:
# userId       False
# movieId      False
# tag          False
# timestamp    False
# dtype: bool

# %%
# DATA VISUALIZATION
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
# %matplotlib inline
ratings.hist(column='rating',figsize=(8,6))
plt.show()

# %%
ratings.boxplot(column='rating',figsize=(8,6))
plt.show()

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tags['userId'].head()
# Out:
# 0    18
# 1    65
# 2    65
# 3    65
# 4    65
# Name: userId, dtype: int64

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
tags[['userId','tag']].head()
# Out:
#    userId            tag
# 0      18    Mark Waters
# 1      65      dark hero
# 2      65      dark hero
# 3      65  noir thriller
# 4      65      dark hero

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
ratings[::-1]
# Out:
#           userId  movieId  rating
# 20000262  138493    71619     2.5
# 20000261  138493    70286     5.0
# 20000260  138493    69644     3.0
# 20000259  138493    69526     4.5
# 20000258  138493    68954     4.5
# ...          ...      ...     ...
# 4              1       50     3.5
# 3              1       47     3.5
# 2              1       32     3.5
# 1              1       29     3.5
# 0              1        2     3.5
#
# [20000263 rows x 3 columns]

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
unique_count = tags['tag'].value_counts()
unique_count
# Out:
# tag
# sci-fi                           3384
# based on a book                  3281
# atmospheric                      2917
# comedy                           2779
# action                           2657
#                                  ...
# Paul Adelstein                      1
# the wig                             1
# killer fish                         1
# genetically modified monsters       1
# topless scene                       1
# Name: count, Length: 38643, dtype: int64

# %%
unique_count[:10].plot(kind='bar',color=['r','g','b','r','g','b','r','g','b','y'])
plt.show()

# %%
high_rated = ratings['rating'] >= 5.0
ratings[high_rated][:10]
# Out:
#      userId  movieId  rating
# 131       1     4993     5.0
# 142       1     5952     5.0
# 158       1     7153     5.0
# 170       1     8507     5.0
# 176       2       62     5.0
# 177       2       70     5.0
# 180       2      260     5.0
# 181       2      266     5.0
# 183       2      480     5.0
# 184       2      541     5.0

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
action_movies = movies['genres'].str.contains('Action')
movies[action_movies]
# Out:
#        movieId                           title  \
# 5            6                     Heat (1995)
# 8            9             Sudden Death (1995)
# 9           10                GoldenEye (1995)
# 14          15         Cutthroat Island (1995)
# 19          20              Money Train (1995)
# ...        ...                             ...
# 27168   130842            Power/Rangers (2015)
# 27187   130984      Santo vs. las lobas (1976)
# 27198   131025         The Brass Legend (1956)
# 27236   131122            Love Exposure (2007)
# 27264   131180  Dead Rising: Watchtower (2015)
#
#                                    genres
# 5                   Action|Crime|Thriller
# 8                                  Action
# 9               Action|Adventure|Thriller
# 14               Action|Adventure|Romance
# 19     Action|Comedy|Crime|Drama|Thriller
# ...                                   ...
# 27168             Action|Adventure|Sci-Fi
# 27187               Action|Fantasy|Horror
# ...

# %%
comedy_movies = movies['genres'].str.contains('Comedy')
movies[comedy_movies]
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 6            7                                     Sabrina (1995)
# ...        ...                                                ...
# 27270   131248                              Brother Bear 2 (2006)
# 27271   131250                              No More School (2000)
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 2                                   Comedy|Romance
# ...

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
ratings_count = ratings[['movieId', 'rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5      239125
# 1.0      680732
# 1.5      279252
# 2.0     1430997
# 2.5      883398
# 3.0     4291193
# 3.5     2200156
# 4.0     5561926
# 4.5     1534824
# 5.0     2898660

# %%
ratings['movieId'].unique().sum()
# Out:
# 1572269395

# %%
movie_mean = ratings[['movieId', 'rating']].groupby('movieId').mean()
movie_mean
# Out:
#            rating
# movieId
# 1        3.921240
# 2        3.211977
# 3        3.151040
# 4        2.861393
# 5        3.064592
# ...           ...
# 131254   4.000000
# 131256   4.000000
# 131258   2.500000
# 131260   3.000000
# 131262   4.000000
#
# [26744 rows x 1 columns]

# %%
movie_count = ratings[['movieId', 'rating']].groupby('movieId').count()
movie_count
# Out:
#          rating
# movieId
# 1         49695
# 2         22243
# 3         12735
# 4          2756
# 5         12161
# ...         ...
# 131254        1
# 131256        1
# 131258        1
# 131260        1
# 131262        1
#
# [26744 rows x 1 columns]

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
temp = movies.merge(tags, on ='movieId')
temp
# Out:
#         movieId               title  \
# 0             1    Toy Story (1995)
# 1             1    Toy Story (1995)
# 2             1    Toy Story (1995)
# 3             1    Toy Story (1995)
# 4             1    Toy Story (1995)
# ...         ...                 ...
# 465543   131258  The Pirates (2014)
# 465544   131258  The Pirates (2014)
# 465545   131258  The Pirates (2014)
# 465546   131258  The Pirates (2014)
# 465547   131258  The Pirates (2014)
#
#                                              genres  userId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy    1644
# 1       Adventure|Animation|Children|Comedy|Fantasy    1741
# 2       Adventure|Animation|Children|Comedy|Fantasy    1741
# 3       Adventure|Animation|Children|Comedy|Fantasy    1741
# 4       Adventure|Animation|Children|Comedy|Fantasy    1741
# ...                                             ...     ...
# 465543                                    Adventure   28906
# ...

# %%
temp = movies.merge(tags, on ='movieId',how='inner')
temp
# Out:
#         movieId               title  \
# 0             1    Toy Story (1995)
# 1             1    Toy Story (1995)
# 2             1    Toy Story (1995)
# 3             1    Toy Story (1995)
# 4             1    Toy Story (1995)
# ...         ...                 ...
# 465543   131258  The Pirates (2014)
# 465544   131258  The Pirates (2014)
# 465545   131258  The Pirates (2014)
# 465546   131258  The Pirates (2014)
# 465547   131258  The Pirates (2014)
#
#                                              genres  userId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy    1644
# 1       Adventure|Animation|Children|Comedy|Fantasy    1741
# 2       Adventure|Animation|Children|Comedy|Fantasy    1741
# 3       Adventure|Animation|Children|Comedy|Fantasy    1741
# 4       Adventure|Animation|Children|Comedy|Fantasy    1741
# ...                                             ...     ...
# 465543                                    Adventure   28906
# ...

# %%
temp = movies.merge(tags, on ='movieId',how='outer')
temp
# Out:
#         movieId                title  \
# 0             1     Toy Story (1995)
# 1             1     Toy Story (1995)
# 2             1     Toy Story (1995)
# 3             1     Toy Story (1995)
# 4             1     Toy Story (1995)
# ...         ...                  ...
# 473276   131258   The Pirates (2014)
# 473277   131258   The Pirates (2014)
# 473278   131258   The Pirates (2014)
# 473279   131260  Rentun Ruusu (2001)
# 473280   131262     Innocence (2014)
#
#                                              genres   userId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy   1644.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   1741.0
# 2       Adventure|Animation|Children|Comedy|Fantasy   1741.0
# 3       Adventure|Animation|Children|Comedy|Fantasy   1741.0
# 4       Adventure|Animation|Children|Comedy|Fantasy   1741.0
# ...                                             ...      ...
# 473276                                    Adventure  28906.0
# ...

# %%
avg_ratings= ratings.groupby('movieId', as_index=False)
avg_ratings.head()
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 19989073  138406   110167     4.5
# 19989074  138406   110169     4.0
# 19989075  138406   110510     4.5
# 19990249  138414   103776     4.0
# 19990261  138414   118876     2.5
#
# [107964 rows x 3 columns]

# %%
avg_ratings= ratings.groupby('movieId', as_index=False).mean()
avg_ratings.head()
# Out:
#    movieId        userId    rating
# 0        1  69282.396821  3.921240
# 1        2  69169.928202  3.211977
# 2        3  69072.079388  3.151040
# 3        4  69652.913280  2.861393
# 4        5  69113.475454  3.064592

# %%
# Vectorised String Operations
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_genres = movies['genres'].str.split('|',expand=True)
movies_genres.head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
# movies_Genres created above.
movies_genres['Comedy'] = movies['genres'].str.contains('Comedy')
movies_genres.head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
#
#       9  Comedy
# 0  None    True
# 1  None   False
# 2  None    True
# 3  None    True
# 4  None    True

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tags.sort_values(by='timestamp',ascending=True)
# Out:
#         userId  movieId              tag            timestamp
# 333932  100371     2788     monty python  2005-12-24 13:00:10
# 333927  100371     1732    coen brothers  2005-12-24 13:00:36
# 333924  100371     1206  stanley kubrick  2005-12-24 13:00:48
# 333923  100371     1193   jack nicholson  2005-12-24 13:02:51
# 333939  100371     5004    peter sellers  2005-12-24 13:03:19
# ...        ...      ...              ...                  ...
# 290535   88044   106782        profanity  2015-03-30 22:21:36
# 288375   87797      215           Vienna  2015-03-30 22:50:01
# 158763   46072     3409      premonition  2015-03-31 00:12:06
# 158780   46072     6058      premonition  2015-03-31 00:12:44
# 339178  102853   115149    russian mafia  2015-03-31 03:09:12
#
# [465548 rows x 4 columns]
